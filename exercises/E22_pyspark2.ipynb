# %% [markdown]
# # Workshop: BigQuery and Spark ML
#
# ### Wednesday, April 17, 2024
#
# Today's exercise will illustrate a bit about how PySpark integrates with other tools we've seen this semester.
#
# Specifically, we'll follow this tutorial from GCP, which uses BigQuery (a large-scale database tool available on GCP, which implements SQL) to retrieve data from a database and uses that data to train a simple regression model using [Apache Spark's MLlib](https://spark.apache.org/docs/latest/).
#
# The tutorial is here:
# https://cloud.google.com/dataproc/docs/tutorials/bigquery-sparkml?hl=en#spark-ml-tutorial_regression-gcloud

# %% [markdown]
# A few helpful notes:
#
# - The tutorial has you copy-paste a big mess of Python code into a file called `natality_sparkml.py`. Trying to do this directly in the cloud shell may or may not lead to a headache, because copy-pasting into vim/nano inside the shell inside your browser can be messy. You may have an easier time creating this Python file on your local machine and then uploading it directly to your storage bucket via the storage browser.
# - When submitting your PySpark job, you need to specify a flag of the form `--jars=gs://spark-lib/bigquery/spark-bigquery-with-dependencies_SCALAVERSION-CONNECTORVERSION.jar`. `SCALAVERSION` should be 2.12 and `CONNECTORVERSION` should be 0.23.2. Thus, the flag should look like `--jars=gs://spark-lib/bigquery/spark-bigquery-with-dependencies_2.12-0.23.2.jar` (this worked as of 9pm Central time on April 18, 2023). <b>Note:</b> this is the kind of thing that out in the real world you will have to hunt down on your own, and it is undoubtedly the most annoying part of the job! You'll get a small taste of this when you do the last homework using TensorFlow on GCP.
# - <b>Don't forget to clean up your session afterwards to avoid spending a bunch of credits!</b> Follow the instructions in the section titled "Clean up": https://cloud.google.com/dataproc/docs/tutorials/bigquery-sparkml?hl=en#clean-up This involves 1) deleting the project (really you can just delete the storage bucket in the storage browser and delete the data set and query results from the BigQuery browser, but deleting the project is easier). 2) Deleting the dataproc clustering following the instructions here: https://cloud.google.com/dataproc/docs/guides/manage-cluster#delete_a_cluster

# %%
# TODO: do the tutorial at the above link.
