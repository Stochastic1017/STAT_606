# %% [markdown]
# # Workshop: Types, Variables and Functions
#
# ### January 29, 2024

# %% [markdown]
# ## Problem 1: Failing on purpose
#
# Adapted from Think Python Problems 1.1 (https://greenteapress.com/thinkpython2/html/thinkpython2002.html#sec14) and 2.1 (https://greenteapress.com/thinkpython2/html/thinkpython2003.html#sec25)
#
# Let's have a look at some different ways that things can go wrong in a line of Python code, so that you'll recognize common errors "in the wild".
#
# Do each of the following, making note of what happens (and try to explain why!).
#
# Hello I am writing this in lecture to demonstrate how to edit a Markdown cell.
#
# Here is more text. Again, just a demo.

# %% [markdown]
# a) When printing, what happens if you leave out one of the parentheses, or both?

# %%
print('hello')
# Out:
# hello

# %%
print('hello'
# Out:
#   Cell In[14], line 1
#     print('hello'
#                  ^
# SyntaxError: incomplete input

# %%
print'hello')
# Out:
#   Cell In[15], line 1
#     print'hello')
#                 ^
# SyntaxError: unmatched ')'

# %% [markdown]
# b) If you are trying to print a string, what happens if you leave out one of the quotation marks, or both?

# %%
print('hello')
# Out:
# hello

# %%
print('hello)
# Out:
#   Cell In[18], line 1
#     print('hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(hello')
# Out:
#   Cell In[20], line 1
#     print(hello')
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# c) You can use a minus sign to make a negative number like -2. What happens if you put a plus sign before a number? What about `2++2`?

# %%
-2
# Out:
# -2

# %%
+2
# Out:
# 2

# %%
++++++2
# Out:
# 2

# %%
2+++++++++2
# Out:
# 4

# %% [markdown]
# d) In math notation, leading zeros are ok, as in 09. What happens if you try this in Python? What about 011?

# %%
09
# Out:
#   Cell In[25], line 1
#     09
#     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
0o11
# Out:
# 9

# %% [markdown]
# e) What happens if you have two values with no operator between them?

# %%
9 9
# Out:
#   Cell In[28], line 1
#     9 9
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# f) We’ve seen that `n = 42` is legal. It's just variable assignment. What about `42 = n`?

# %%
n = 42

# %%
n
# Out:
# 42

# %%
42 = n
# Out:
#   Cell In[34], line 1
#     42 = n
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
var42 = n # Python variable names cannot start with a number.

# %%
var42
# Out:
# 42

# %% [markdown]
# g) How about `x = y = 1`?

# %%
x = y = 1

# %%
x
# Out:
# 1

# %%
y
# Out:
# 1

# %% [markdown]
# h) In some languages every statement ends with a semi-colon, `;` (for example, Java and C require this). Other languages require semi-colons in some contexts, but not others (R is like this). What happens if you put a semi-colon at the end of a Python statement?

# %%
print('hello')
# Out:
# hello

# %%
print('hello');
# Out:
# hello

# %% [markdown]
# Here's some funny behavior:

# %%
;
# Out:
# ''

# %% [markdown]
# This actually has to do with ipython, which is part of jupyter: https://ipython.readthedocs.io/en/latest/interactive/reference.html#automatic-parentheses-and-quotes

# %% [markdown]
# i) What if you put a period at the end of a statement?

# %%
print('hello').
# Out:
#   Cell In[47], line 1
#     print('hello').
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# j) In math notation you can multiply x and y like this: x y. What happens if you try that in Python?

# %%
x y
# Out:
#   Cell In[48], line 1
#     x y
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# k) What happens if you try to reference (i.e., retrieve the value of) a variable that you haven't declared yet? For examaple, what happens if you write `2*does_not_exist`?

# %%
2*does_not_exist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 2*does_not_exist
#
# NameError: name 'does_not_exist' is not defined

# %% [markdown]
# ## Problem 2: Solving a word problem
#
# Adapted from Think Python problem 2.2 (https://greenteapress.com/thinkpython2/html/thinkpython2003.html#sec25)
#
# Okay, time to very briefly relive the nightmare of word problems (https://en.wikipedia.org/wiki/Word_problem_(mathematics_education)), not to be confused with word problems (https://en.wikipedia.org/wiki/Word_problem_(mathematics)):
#
# a) Suppose the cover price of a book is \\$24.95, but bookstores get a 40\% discount. Shipping costs \\$3 for the first copy and 75 cents for each additional copy. What is the total wholesale cost (i.e., the total amount that the bookstore has to pay) for 60 copies? Use Python as a calculator to find the answer.

# %%
60*(1-0.4)*24.95 + 3 + 0.75*(60-1)
# Out:
# 945.4499999999999

# %% [markdown]
# b) Generalize the above by writing a function `wholesale(ncopies, covprice, discount, initialship, addlcost)` that computes the wholesale cost of ordering `ncopies` (a non-negative integer) books with cover price `covprice` (a positive float), at a bookstore discount rate `discount` (a float between 0.0 and 1.0), with a shipping cost of `initialship` (a non-negative float) for the first copy and a shipping cost of `addlcost` (a non-negative float), and returns the answer as a float.

# %%
def wholesale( ncopies, covprice, discount, initialship, addlshipcost ):
    if ncopies==0:
        return 0.0
    bookprice = ncopies*(1-discount)*covprice
    shippingprice = initialship + (ncopies-1)*addlshipcost
    total_price = bookprice + shippingprice
    return total_price

# %%
wholesale( 60, 24.95, 0.4, 3, .75) # Should evaluate to the same as your answer above.
# Out:
# 945.4499999999999

# %%
wholesale( 0, 24.95, 0.4, 3, .75) # Should evaluate to 0.0
# Out:
# 0.0

# %%
wholesale( -1, 24.95, 0.4, 3, .75)
# Out:
# -13.469999999999999

# %% [markdown]
# c) Now, take your function from above and try giving the "wrong" arguments. For example, what happens if you set the discount to be the string `cat`? What if you make `covprice` a negative number?

# %%
wholesale( 'lizard', 24.95, 0.4, 3, .75)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 wholesale( 'lizard', 24.95, 0.4, 3, .75)
#
# Cell In[60], line 4, in wholesale(ncopies, covprice, discount, initialship, addlshipcost)
#       2 if ncopies==0:
#       3     return 0.0
# ----> 4 bookprice = ncopies*(1-discount)*covprice
#       5 shippingprice = initialship + (ncopies-1)*addlshipcost
#       6 total_price = bookprice + shippingprice
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
3.14*'lizard'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 3.14*'lizard'
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
# Note that we CAN do
3*'lizard'
# Out:
# 'lizardlizardlizard'

# %% [markdown]
# In a few lectures, we'll talk about ways to avoid these weird situations by adding <b>error checking</b> to our code.

# %% [markdown]
# ## Problem 3: First Class Functions
#
# Python has what are called *first class functions*. That is a fancy way of saying that variables can have a function value just as easily as they can have, say, a string value or an integer value.
#
# Here's an illustration.

# %%
def silly_function():
    print('Go Badgers!')
    
x = silly_function

# %% [markdown]
# a) We just created a variable called `x`. What is its value?

# %%
x
# Out:
# <function __main__.silly_function()>

# %%
type( x ) # x is of type function. This makes sense-- silly_function is a function!
# Out:
# function

# %% [markdown]
# Answer here (or just say the answer to yourself)
#
# `x` stores the function `silly_function` as its value.

# %% [markdown]
# b) What do you think will happen if we retrieve the value of the variable `x`? After making a prediction, try it.

# %%
x
# Out:
# <function __main__.silly_function()>

# %% [markdown]
# c) What do you think will happen if we write `x()`? After making a prediction, try it.

# %%
x()
# Out:
# Go Badgers!

# %%
# Contrast with this
silly_function()
# Out:
# Go Badgers!

# %% [markdown]
# d) Now let's get fancy. Write a function `do_twice` that takes a single function as its argument, and calls that function twice. That is, if `f` is a function, `do_twice(f)` calls the function `f` twice. You may assume that the function `f` takes no arguments, i.e., is called as `f()`.

# %%
def do_twice( f ):
    f()
    f()

# %% [markdown]
# Use `do_twice` to call `silly_function()` twice, thus printing the string `'Go Badgers!'` twice.

# %%
do_twice( silly_function )
# Out:
# Go Badgers!
# Go Badgers!

# %% [markdown]
# We'll have a lot more to say about this when we talk about functional programming in a few weeks. For now, it's just an interesting quirk of variables in Python (actually, most programs support this-- Java, C/C++, MATLAB, R...). The "name" that refers to a function is called a *function handle*. It's a way to refer to a function without calling it!
