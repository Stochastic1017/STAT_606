# %%
import requests

# %%
# My API key, which I got from Yelp
# https://www.yelp.com/developers/documentation/v3/get_started
yelp_api_key='Get a Yelp API key and paste it here.'

# %%
import requests
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api_key}
url_params = {'term': 'coffee', # Search for coffee...
              'radius': 1000, # ...within 1000 meters...
              # ...near the statistics department
              'location': '1300 University Ave, Madison WI'}
r = requests.get(url, headers=headers, params=url_params)
r.json()
# Out:
# {'businesses': [{'id': 'k76zkFY6PbIW4T_Riq15pQ',
#    'alias': 'indie-coffee-madison',
#    'name': 'Indie Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IXXZ02FWtDXANjEZdzm1DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indie-coffee-madison?adjust_creative=GoPDP3IZmcqNt7RZyPNigA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GoPDP3IZmcqNt7RZyPNigA',
#    'review_count': 128,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.067526, 'longitude': -89.406553},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1225 Regent St',
#     'address2': '',
#     'address3': '',
#     'city': 'Madison',
#     'zip_code': '53715',
#     'country': 'US',
#     'state': 'WI',
#     'display_address': ['1225 Regent St', 'Madison, WI 53715']},
#    'phone': '+16082599621',
#    'display_phone': '(608) 259-9621',
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % yelp_api_key}
url_params = {'term': 'coffee', # Search for coffee...
              'radius': 1000, # ...within 1000 meters...
              # ...near the statistics department
              'location': '1300 University Ave, Madison WI'}
r = requests.get(url, headers=headers, params=url_params)
[res['alias'] for res in r.json()['businesses']]
# Out:
# ['indie-coffee-madison',
#  'peets-coffee-madison-2',
#  'valentia-coffee-madison',
#  'aldos-cafe-madison',
#  'a-just-brew-madison',
#  'java-den-at-1022-madison',
#  'greenbush-bakery-madison',
#  'the-library-cafe-and-bar-madison',
#  'prairie-fire-madison',
#  'mcdonalds-madison-27',
#  'mickies-dairy-bar-madison',
#  'saigon-sandwich-madison-madison',
#  'babcock-hall-dairy-store-madison',
#  'badger-market-union-south-madison',
#  'der-rathskeller-madison',
#  'kwik-trip-madison-3',
#  'daily-scoop-in-memorial-union-madison',
#  'orange-tree-imports-madison',
#  'the-wise-madison',
#  'capital-cafe-madison']

# %%
r.url
# Out:
# 'https://api.yelp.com/v3/businesses/search?term=coffee&radius=1000&location=1300+University+Ave%2C+Madison+WI'

# %%
r = requests.get(url, headers=headers, params=url_params)
[res['alias'] for res in r.json()['businesses']]
# Out:
# ['indie-coffee-madison',
#  'peets-coffee-madison-2',
#  'valentia-coffee-madison',
#  'aldos-cafe-madison',
#  'a-just-brew-madison',
#  'java-den-at-1022-madison',
#  'greenbush-bakery-madison',
#  'the-library-cafe-and-bar-madison',
#  'prairie-fire-madison',
#  'mcdonalds-madison-27',
#  'mickies-dairy-bar-madison',
#  'saigon-sandwich-madison-madison',
#  'babcock-hall-dairy-store-madison',
#  'badger-market-union-south-madison',
#  'der-rathskeller-madison',
#  'kwik-trip-madison-3',
#  'daily-scoop-in-memorial-union-madison',
#  'orange-tree-imports-madison',
#  'the-wise-madison',
#  'capital-cafe-madison']

# %%
r = requests.get(url, headers=headers, params=url_params)
[res['alias'] for res in r.json()['businesses']]
# Out:
# ['indie-coffee-madison',
#  'peets-coffee-madison-2',
#  'valentia-coffee-madison',
#  'aldos-cafe-madison',
#  'a-just-brew-madison',
#  'java-den-at-1022-madison',
#  'greenbush-bakery-madison',
#  'the-library-cafe-and-bar-madison',
#  'prairie-fire-madison',
#  'mcdonalds-madison-27',
#  'mickies-dairy-bar-madison',
#  'saigon-sandwich-madison-madison',
#  'babcock-hall-dairy-store-madison',
#  'badger-market-union-south-madison',
#  'der-rathskeller-madison',
#  'kwik-trip-madison-3',
#  'daily-scoop-in-memorial-union-madison',
#  'orange-tree-imports-madison',
#  'the-wise-madison',
#  'capital-cafe-madison']
